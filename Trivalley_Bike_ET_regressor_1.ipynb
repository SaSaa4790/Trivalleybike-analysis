# %%
# Code snippet 0
# Installing pycaret AI package for ML modeling
# !pip install -U --pre pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 19.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 22.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 44.4 MB/s eta 0:00:00
# ...

# %%
# Code snippet 1
# Installing pandas and numpy for numerical calulcations)
import pandas as pd
import numpy as np

# %%
# Code snippet 2
# Importing the dataset
data  = pd.read_csv ('https://docs.google.com/spreadsheets/d/e/2PACX-1vSifbk44BcWITC1-_Q8O9Q0Vzs20FLIWZyTbbt9TjxI5nZUdLFYxO_wgy2J77fkVvzJ0lTVLvGn9GIP/pub?gid=0&single=true&output=csv')



# Displaying the data
data
# Out:
#        CustomerID  AveMonthSpend  BikeBuyer Title  FirstName MiddleName  \
# 0           11000             89          0   NaN        Jon          V
# 1           11001            117          1   NaN     Eugene          L
# 2           11002            123          0   NaN      Ruben        NaN
# 3           11003             50          0   NaN    Christy        NaN
# 4           11004             95          1   NaN  Elizabeth        NaN
# ...           ...            ...        ...   ...        ...        ...
# 16514       13121            101          0   NaN    Latasha          E
# 16515       26100             46          0   NaN      James     Garner
# 16516       11328             79          0   NaN     Julian          M
# 16517       23077             65          0   NaN     Marvin          A
# 16518       18982             68          0   NaN       Kyle        NaN
#
#          LastName Suffix         AddressLine1 AddressLine2  ...   BirthDate  \
# ...

# %%
# Code snippet 3
# Displaying column names
data.columns
# Out:
# Index(['CustomerID', 'AveMonthSpend', 'BikeBuyer', 'Title', 'FirstName',
#        'MiddleName', 'LastName', 'Suffix', 'AddressLine1', 'AddressLine2',
#        'City', 'StateProvinceName', 'CountryRegionName', 'PostalCode',
#        'PhoneNumber', 'BirthDate', 'Education', 'Occupation', 'Gender',
#        'MaritalStatus', 'HomeOwnerFlag', 'NumberCarsOwned',
#        'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome'],
#       dtype='object')

# %%
# Code snippet 4
# Set ignored columns (noise/redundant variables/missing data variables)
ignored_cols = ['BikeBuyer', 'FirstName', 'LastName', 'AddressLine1', 'PhoneNumber',
'Title', 'MiddleName', 'Suffix', 'AddressLine2']

# %%
# Code snippet 5
# Setting the numerical columns
num_cols = ['CustomerID', 'NumberCarsOwned',
       'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome']

# %%
# Code snippet 6
# Setting the categorical columns
cat_cols = ['City', 'StateProvinceName', 'CountryRegionName', 'PostalCode', 'BirthDate', 'Education', 'Occupation', 'Gender',
       'MaritalStatus', 'HomeOwnerFlag']

# %%
# Code snippet 7
# Setting the target variable
y = 'AveMonthSpend'

# %%
# Code snippet 8
# Importing regression modules from pycaret
from pycaret.regression import *

# %%
# Code snippet 9
# Setting/configuring pycaret ML modeling experiment
regression_model_setup = setup(data,
                              target = y,
                              ignore_features = ignored_cols,
                              numeric_features = num_cols,
                              categorical_features = cat_cols)
# Out:
# <style type="text/css">
# #T_5908c_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5908c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5908c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5908c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5908c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5908c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5908c_row0_col1" class="data row0 col1" >3249</td>
#     </tr>
#     <tr>
#       <th id="T_5908c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5908c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5908c_row1_col1" class="data row1 col1" >AveMonthSpend</td>
#     </tr>
#     <tr>
#       <th id="T_5908c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Code snippet 10
# Invoking ML algorithms
compare_models()
# Out:
# <style type="text/css">
# #T_88572 th {
#   text-align: left;
# }
# ...

# %%
# Code snippet 11
# Performing cross validation using the best algorithm
regression_model = create_model('et')
# Out:
# <style type="text/css">
# #T_72ed3_row10_col0, #T_72ed3_row10_col1, #T_72ed3_row10_col2, #T_72ed3_row10_col3, #T_72ed3_row10_col4, #T_72ed3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_72ed3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72ed3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_72ed3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_72ed3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_72ed3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_72ed3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_72ed3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
# Code snippet 12
# Importing the client dataset(for which the standard scores need to be predicted)
client_data = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTkZJ1CrmqZMztU1v7VShkyyP65Ujjhd4unSPyg6WDYd95DqRVyapFCyPI7TAKLtf4u6AJb7sn4pqJm/pub?gid=0&single=true&output=csv')

# Displaying the client data shape
client_data.columns
# Out:
# Index(['CustomerID', 'City', 'StateProvinceName', 'CountryRegionName',
#        'PostalCode', 'BirthDate', 'Education', 'Occupation', 'Gender',
#        'MaritalStatus', 'HomeOwnerFlag', 'NumberCarsOwned',
#        'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome'],
#       dtype='object')

# %%
# Code snippet 13
# Predicting ave month spend listed in the client dataset
client_data_predictions = predict_model(regression_model, client_data)

# %%
# Code snippet 14
# Displaying the predicted ave month spend on the client dataset
client_data_predictions
# Out:
#        CustomerID           City StateProvinceName CountryRegionName  \
# 0           58772        Seaford          Victoria         Australia
# 1           98594     North Ryde   New South Wales         Australia
# 2           96960     Wollongong   New South Wales         Australia
# 3           72891  East Brisbane        Queensland         Australia
# 4           74195    Warrnambool          Victoria         Australia
# ...           ...            ...               ...               ...
# 13188       55020        Sunbury          Victoria         Australia
# 13189       77277         Melton          Victoria         Australia
# 13190       96565        Shawnee  British Columbia            Canada
# 13191       79375         Rhodes   New South Wales         Australia
# 13192       52536       Kirkland        Washington     United States
#
#       PostalCode   BirthDate        Education      Occupation Gender  \
# ...
